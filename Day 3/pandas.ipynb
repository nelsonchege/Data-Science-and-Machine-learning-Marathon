# %%
import pandas as pd

gdp = pd.read_csv('gdp_per_capita.csv')
# gdp = pd.read_csv('gdp_per_capita.xlsx') for excel file
# gdp = pd.read_csv('gdp_per_capita.txt',delimiter ='\t') fro txt file
gdp
# Out:
#                     Country Name Code        1960        1961        1962  \
# 0                          Aruba  ABW         NaN         NaN         NaN
# 1    Africa Eastern and Southern  AFE  147.612227  147.014904  156.189192
# 2                    Afghanistan  AFG   59.773234   59.860900   58.458009
# 3     Africa Western and Central  AFW  107.932233  113.081647  118.831107
# 4                         Angola  AGO         NaN         NaN         NaN
# ..                           ...  ...         ...         ...         ...
# 261                       Kosovo  XKX         NaN         NaN         NaN
# 262                  Yemen, Rep.  YEM         NaN         NaN         NaN
# 263                 South Africa  ZAF  443.009920  454.962013  473.011405
# 264                       Zambia  ZMB  232.188564  220.042067  212.578449
# 265                     Zimbabwe  ZWE  278.813847  280.828663  276.688233
#
#            1963        1964        1965        1966        1967  ...  \
# ...

# %%
gdp.columns
# Out:
# Index(['Country Name', 'Code', '1960', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
#        '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', 'Unnamed: 65'],
#       dtype='object')

# %%
gdp['Country Name'][121]
# Out:
# 'Kenya'

# %%
gdp.iloc[121:131]
# Out:
#                                           Country Name Code        1960  \
# 121                                              Kenya  KEN   97.445501
# 122                                    Kyrgyz Republic  KGZ         NaN
# 123                                           Cambodia  KHM  111.342441
# 124                                           Kiribati  KIR         NaN
# 125                                St. Kitts and Nevis  KNA  241.539163
# 126                                        Korea, Rep.  KOR  158.249303
# 127                                             Kuwait  KWT         NaN
# 128  Latin America & Caribbean (excluding high income)  LAC         NaN
# 129                                            Lao PDR  LAO         NaN
# 130                                            Lebanon  LBN         NaN
#
#            1961        1962        1963        1964         1965         1966  \
# 121   94.651293  100.394495  103.778721  108.293688   104.711674   118.207910
# ...

# %%
gdp.iloc[121,0]
# Out:
# 'Kenya'

# %%
for index ,row in gdp.iterrows():
    print(index,row['Country Name'])
# Out:
# 0 Aruba
# 1 Africa Eastern and Southern
# 2 Afghanistan
# 3 Africa Western and Central
# 4 Angola
# 5 Albania
# 6 Andorra
# 7 Arab World
# 8 United Arab Emirates
# 9 Argentina
# 10 Armenia
# 11 American Samoa
# 12 Antigua and Barbuda
# 13 Australia
# 14 Austria
# 15 Azerbaijan
# 16 Burundi
# 17 Belgium
# 18 Benin
# 19 Burkina Faso
# 20 Bangladesh
# 21 Bulgaria
# 22 Bahrain
# 23 Bahamas, The
# 24 Bosnia and Herzegovina
# 25 Belarus
# 26 Belize
# 27 Bermuda
# 28 Bolivia
# 29 Brazil
# 30 Barbados
# 31 Brunei Darussalam
# 32 Bhutan
# 33 Botswana
# 34 Central African Republic
# 35 Canada
# 36 Central Europe and the Baltics
# 37 Switzerland
# 38 Channel Islands
# 39 Chile
# 40 China
# 41 Cote d'Ivoire
# 42 Cameroon
# 43 Congo, Dem. Rep.
# 44 Congo, Rep.
# 45 Colombia
# 46 Comoros
# 47 Cabo Verde
# 48 Costa Rica
# 49 Caribbean small states
# 50 Cuba
# 51 Curacao
# 52 Cayman Islands
# 53 Cyprus
# 54 Czech Republic
# 55 Germany
# 56 Djibouti
# 57 Dominica
# 58 Denmark
# 59 Dominican Republic
# ...

# %%
gdp.loc[gdp['2009']>= 20000]
# Out:
#                   Country Name Code         1960         1961         1962  \
# 0                        Aruba  ABW          NaN          NaN          NaN
# 6                      Andorra  AND          NaN          NaN          NaN
# 8         United Arab Emirates  ARE          NaN          NaN          NaN
# 13                   Australia  AUS  1810.619230  1877.616638  1854.656834
# 14                     Austria  AUT   935.460427  1031.815004  1087.834243
# 17                     Belgium  BEL  1273.691659  1350.197673  1438.523233
# 23                Bahamas, The  BHS  1550.267699  1651.317673  1752.840006
# 27                     Bermuda  BMU  1902.402119  1961.538169  2020.385965
# 31           Brunei Darussalam  BRN          NaN          NaN          NaN
# 35                      Canada  CAN  2259.294285  2240.433039  2268.585346
# 37                 Switzerland  CHE  1787.360348  1971.316323  2131.391652
# ...

# %%
gdp.describe()
# Out:
#               1960         1961         1962         1963         1964  \
# count   128.000000   134.000000   137.000000   137.000000   137.000000
# mean    482.725314   491.115624   513.103203   544.566319   590.805091
# std     626.040168   639.846845   669.060194   708.534576   774.925619
# min      40.537211    26.308357    26.985920    28.449430    20.035487
# 25%     104.407303   109.078291   114.581807   121.762130   123.645925
# 50%     197.897848   197.158225   203.437370   213.896759   234.633358
# 75%     478.826988   475.192902   520.206131   583.411562   629.591526
# max    3007.123445  3066.562869  3243.843078  3374.515171  3573.941185
#
#               1965         1966         1967         1968         1969  ...  \
# count   148.000000   151.000000   154.000000   159.000000   159.000000  ...
# mean    654.822693   710.326019   725.993794   742.735017   804.348363  ...
# std     864.084238   935.096499   966.070357   994.686146  1071.190027  ...
# ...

# %%
gdp.sort_values(['2008'], ascending =False)
# Out:
#                   Country Name Code         1960         1961         1962  \
# 149                     Monaco  MCO          NaN          NaN          NaN
# 137              Liechtenstein  LIE          NaN          NaN          NaN
# 144                 Luxembourg  LUX  2242.015817  2222.366366  2311.798849
# 27                     Bermuda  BMU  1902.402119  1961.538169  2020.385965
# 177                     Norway  NOR  1441.755660  1560.324931  1667.247430
# ..                         ...  ...          ...          ...          ...
# 193  Korea, Dem. People's Rep.  PRK          NaN          NaN          NaN
# 199           French Polynesia  PYF          NaN          NaN          NaN
# 213                    Somalia  SOM    65.479716    68.106397    70.813049
# 225  Sint Maarten (Dutch part)  SXM          NaN          NaN          NaN
# 255     British Virgin Islands  VGB          NaN          NaN          NaN
#
# ...

# %%
gdp['Total'] = gdp.iloc[:,11:].sum(axis=1)

# %%
gdp.columns
# Out:
# Index(['Country Name', 'Code', '1960', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
#        '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', 'Unnamed: 65', 'Total'],
#       dtype='object')

# %%
twentyonec=gdp.sort_values(['Total'], ascending =False)
twentyonec.reset_index(drop = True, inplace = True )
twentyonec.to_csv('twentyone.csv')
twentyonec.iloc[1:50]
# Out:
#                  Country Name Code         1960         1961         1962  \
# 1               Liechtenstein  LIE          NaN          NaN          NaN
# 2                  Luxembourg  LUX  2242.015817  2222.366366  2311.798849
# 3                     Bermuda  BMU  1902.402119  1961.538169  2020.385965
# 4                 Switzerland  CHE  1787.360348  1971.316323  2131.391652
# 5                      Norway  NOR  1441.755660  1560.324931  1667.247430
# 6                       Qatar  QAT          NaN          NaN          NaN
# 7                     Denmark  DNK          NaN          NaN          NaN
# 8               United States  USA  3007.123445  3066.562869  3243.843078
# 9                     Iceland  ISL  1414.982269  1418.125870  1562.230730
# 10                     Sweden  SWE  2114.002973  2288.921701  2468.694589
# 11              North America  NAC  2939.448335  2991.592897  3155.097538
# 12       United Arab Emirates  ARE          NaN          NaN          NaN
# ...

# %%
gdp.cumsum()
# Out:
#                                           Country Name  \
# 0                                                Aruba
# 1                     ArubaAfrica Eastern and Southern
# 2          ArubaAfrica Eastern and SouthernAfghanistan
# 3    ArubaAfrica Eastern and SouthernAfghanistanAfr...
# 4    ArubaAfrica Eastern and SouthernAfghanistanAfr...
# ..                                                 ...
# 261  ArubaAfrica Eastern and SouthernAfghanistanAfr...
# 262  ArubaAfrica Eastern and SouthernAfghanistanAfr...
# 263  ArubaAfrica Eastern and SouthernAfghanistanAfr...
# 264  ArubaAfrica Eastern and SouthernAfghanistanAfr...
# 265  ArubaAfrica Eastern and SouthernAfghanistanAfr...
#
#                                                   Code          1960  \
# 0                                                  ABW           NaN
# 1                                               ABWAFE    147.612227
# 2                                            ABWAFEAFG    207.385461
# ...
